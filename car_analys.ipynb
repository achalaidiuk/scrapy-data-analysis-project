# %%
import pandas as pd

# %%
df = pd.read_csv('cars.csv')
df
# Out:
#              car       color      engine   fuel_type   gearbox  horsepower  \
# 0          Skoda       Білий           2      Дизель   Автомат         116
# 1            BMW       Білий           2      Бензин   Автомат         476
# 2           Ford       Сірий           2      Гібрид   Автомат         180
# 3         Nissan       Сірий  Не вказано     Електро   Автомат         109
# 4          Tesla       Білий  Не вказано     Електро   Автомат         513
# ...          ...         ...         ...         ...       ...         ...
# 3929  Volkswagen       Білий  Не вказано     Електро   Автомат         136
# 3930      Toyota      Чорний           2      Бензин   Автомат  Не вказано
# 3931      Daewoo  Не вказано         1.6      Бензин  Механіка  Не вказано
# 3932       Новий  Не вказано  Не вказано  Не вказано   Автомат  Не вказано
# 3933       Новий  Не вказано  Не вказано  Не вказано   Автомат  Не вказано
#
#          mileage                    model       price   year
# ...

# %%
df.fillna(0, inplace=True)
df
# Out:
#              car       color      engine   fuel_type   gearbox  horsepower  \
# 0          Skoda       Білий           2      Дизель   Автомат         116
# 1            BMW       Білий           2      Бензин   Автомат         476
# 2           Ford       Сірий           2      Гібрид   Автомат         180
# 3         Nissan       Сірий  Не вказано     Електро   Автомат         109
# 4          Tesla       Білий  Не вказано     Електро   Автомат         513
# ...          ...         ...         ...         ...       ...         ...
# 3929  Volkswagen       Білий  Не вказано     Електро   Автомат         136
# 3930      Toyota      Чорний           2      Бензин   Автомат  Не вказано
# 3931      Daewoo  Не вказано         1.6      Бензин  Механіка  Не вказано
# 3932       Новий  Не вказано  Не вказано  Не вказано   Автомат  Не вказано
# 3933       Новий  Не вказано  Не вказано  Не вказано   Автомат  Не вказано
#
#          mileage                    model       price   year
# ...

# %%
df.to_csv('filtered_cars.csv', index=False)
